# %% [markdown]
# """
# translation_dict = a dictionary loaded from the file translations.json or {} if the file is empty
# for each row of the df
#   try
#     if row[header] in not in translation_dict then
#       translation_dict[row[header]] = translator.translate
#       # since our list of translations has been updated, lets store it to a file so we don't lose it
#       store_the_updated tranlation_dict to translations.json
#
#     row[new_header] = translation_dict[row[header]]
#   except
#     # retry the row up to 3 times, 15 seconds apart, if more than that quit and try again later
#     mm

# %% [markdown]
# #### https://stackoverflow.com/questions/29794959/pandas-add-new-column-to-dataframe-from-dictionary
# import pandas as pd
# import json
# from googletrans import Translator
# translator = Translator()
#
# with open("data/TG_MarchenkoUPD.csv", mode="r") as incoming_csv:
#         data = pd.read_csv(incoming_csv, low_memory=False)
# with open("data/TG_MarchenkoUPD.json", mode="r") as outgoing_json:
#             try:
#                 translation_dictionary_test = pd.read_json(outgoing_json)
#                 print("bingo!")
#             except ValueError:
#                 translation_dictionary_test = {}
#                 print("value_error")

# %% [markdown]
# to_translation = ["work","hopes"]
# translation_dictionary = {}
#
# for column in to_translation:
#     translation_dictionary[column]=None
#     translation_dictionary_test[column]=None
#
#
# print("made a translation dictionary:\n",translation_dictionary)

# %% [markdown]
# print(translation_dictionary)
#
# import os.path
# os.path.isfile("data/TG_MarchenkoUPD.json")
#
# result = json.dumps(translation_dictionary_test, indent = 3)
# result
#
# with open('data/TG_MarchenkoUPD.json', 'w') as fp:
#     json.dump(result, fp)

# %% [markdown]
# with open('data/TG_MarchenkoUPD.json', 'r') as test:
#     opening = pd.read_json(test)

# %% [markdown]
# data["hopes_ENG"] = data["hopes"].map(translation_dictionary)
# #### print(data["hopes_ENG"],data["hopes"])
#
# for x in data["hopes"]:
#     print(x)

# %%
import json
import os
import pandas as pd
from googletrans import Translator
import time

translator = Translator()


# TODO: redo temporary path-to-files and translation options
path_to_file = "data/TG_MarchenkoUPD"
csv_to_translate = path_to_file + ".csv"
temporary_json = path_to_file + ".json"
# to_translation = ["work", "hopes"]

# # check if exists
# if os.path.isfile(temporary_json):
#     # with open(temporary_json, mode='w') as json_file:
#     #     translation_dictionary = json.load(json_file)
#     print("Temporary file detected and will be loaded")
# else:
#     translation_dictionary = {}
#     print("No temporary file detected. It will be created and saved")

with open(csv_to_translate, mode="r") as csv_file:
    data = pd.read_csv(csv_file, low_memory=False)

try:
    with open(temporary_json, 'r') as f:
        translation_dictionary = json.load(f)
except json.decoder.JSONDecodeError as e:
    # if no file exists, just start with an empty dict
    print(e, type(e))
    translation_dictionary = {}

for row in data['work'].unique():
    print(row)
    if row in translation_dictionary:
        print("yiss")
    else:
        print("nah")
        translation_dictionary[row] = translator.translate(row).text
        time.sleep(1)
        with open(temporary_json, 'w') as t:
            temp = json.dump(translation_dictionary, t)
        print(type(temp))
# Out:
# Специалист-фрилансер (таргет, СММ, копирайтинг, сторисмейкинг и.т.д)
# yiss
# Строитель
# yiss
# Работаю в найме
# yiss
# Учусь в школе/универе
# yiss
# пенсионерка
# yiss
# Врач
# yiss
# Домохозяйка
# yiss
# Учитель
# yiss
# Топ-менеджмент
# yiss
#  Пенсионер
# yiss
# пенсионер
# yiss
# Инвестициями (недвижка/фондовый рынок)
# yiss
# Собственный бизнес
# yiss
# Продюсер/эксперт/блогер
# yiss
# взял перерыв от работы, учусь трейдингу
# yiss
# Занимаюсь криптовалютой
# yiss
# Пенсионер
# yiss
# Багермейстер
# yiss
# Музыкант
# yiss
# Домохозяйка
# yiss
# В декрете
# yiss
# Гос служба
# yiss
# На данный момент не работаю, имею инвалидность 1-й группы
# yiss
# Госслужащий
# yiss
# Не работаю
# yiss
# Пенсионер
# yiss
# домохозяйка
# yiss
# Футболист
# yiss
# В отпуске по уходу за ребёнком до 3- х лет
# yiss
# IT
# yiss
# Работаю в найм и учусь на бизнес-аналитика
# yiss
# Мама😀
# yiss
# Работаю в найме, фрилансер и инвестирую
# yiss
# другое
# yiss
# Агент недвижимости
# yiss
# ...

# %%
data["work_ENG"] = data["work"].map(translation_dictionary)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 409 entries, 0 to 408
# Data columns (total 20 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   timestamp   409 non-null    object
#  1   age         409 non-null    object
#  2   subscribed  409 non-null    object
#  3   work        409 non-null    object
#  4   like        409 non-null    object
#  5   add         409 non-null    object
#  6   expert      409 non-null    object
#  7   invest      409 non-null    object
#  8   income      409 non-null    object
#  9   capital     409 non-null    object
#  10  roi         312 non-null    object
#  11  passive     409 non-null    object
#  12  hopes       409 non-null    object
#  13  pains       409 non-null    object
#  14  barriers    203 non-null    object
#  15  area        409 non-null    object
#  16  area_m      409 non-null    object
#  17  buy         409 non-null    object
#  18  price       409 non-null    object
# ...
